# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('concrete.csv')
df
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5      0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5      0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4      0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# ...

# %%
df.isnull()
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer     CA     FA    Age  \
# 0      False  False    False  False             False  False  False  False
# 1      False  False    False  False             False  False  False  False
# 2      False  False    False  False             False  False  False  False
# 3      False  False    False  False             False  False  False  False
# 4      False  False    False  False             False  False  False  False
# ...      ...    ...      ...    ...               ...    ...    ...    ...
# 1025   False  False    False  False             False  False  False  False
# 1026   False  False    False  False             False  False  False  False
# 1027   False  False    False  False             False  False  False  False
# 1028   False  False    False  False             False  False  False  False
# 1029   False  False    False  False             False  False  False  False
#
#         CMS
# 0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
df.isnull().sum()
# Out:
# Cement              0
# Blast               0
# Fly Ash             0
# Water               0
# Superplasticizer    0
# CA                  0
# FA                  0
# Age                 0
# CMS                 0
# dtype: int64

# %%
sns.heatmap(df.isnull(),annot=True)

# %%
df.corr()
# Out:
#                     Cement     Blast   Fly Ash     Water  Superplasticizer  \
# Cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# Blast            -0.275216  1.000000 -0.323580  0.107252          0.043270
# Fly Ash          -0.397467 -0.323580  1.000000 -0.256984          0.377503
# Water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# Superplasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# CA               -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# FA               -0.222718 -0.281603  0.079108 -0.450661          0.222691
# Age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# CMS               0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                         CA        FA       Age       CMS
# Cement           -0.109349 -0.222718  0.081946  0.497832
# Blast            -0.283999 -0.281603 -0.044246  0.134829
# ...

# %%
sns.heatmap(df.corr(), annot=True)

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#             Cement        Blast      Fly Ash        Water  Superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#                 CA           FA          Age          CMS
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# ...

# %%
df.columns
# Out:
# Index(['Cement', 'Blast', 'Fly Ash', 'Water', 'Superplasticizer', 'CA', 'FA',
#        'Age', 'CMS'],
#       dtype='object')

# %%
df['Cement'].plot.box()

# %%
df['Blast'].plot.box()

# %%
df['Superplasticizer'].plot.box()

# %%
# Here we can see that there are outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[2.47791487, 0.85688789, 0.84714393, ..., 1.21767004, 0.27973311,
#         2.64540763],
#        [2.47791487, 0.85688789, 0.84714393, ..., 1.21767004, 0.27973311,
#         1.56142148],
#        [0.49142531, 0.79552649, 0.84714393, ..., 2.24091709, 3.55306569,
#         0.26662698],
#        ...,
#        [1.27008832, 0.75957923, 0.85063487, ..., 0.0801067 , 0.27973311,
#         0.72572939],
#        [1.16860982, 1.30806485, 0.84714393, ..., 0.19116644, 0.27973311,
#         0.18253855],
#        [0.19403325, 0.30849909, 0.3769452 , ..., 0.15074782, 0.27973311,
#         0.20469738]])

# %%
threshold=3
np.where(z>3)
# Out:
# (array([  2,   3,   4,   6,  12,  17,  24,  25,  26,  30,  31,  33,  34,
#          35,  41,  42,  56,  60,  61,  63,  65,  66,  76,  79,  99, 102,
#         122, 125, 145, 148, 168, 171, 553, 559, 571, 584, 604, 610, 616,
#         620, 622, 756, 769, 792, 798, 814, 820, 873, 936], dtype=int64),
#  array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 1, 1, 1, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 3, 3], dtype=int64))

# %%
z[2][7]
# Out:
# 3.553065687407453

# %%
z[3][7]
# Out:
# 5.057676786792999

# %%
z[4][7]
# Out:
# 4.978486728930601

# %%
z[936][3]
# Out:
# 3.0609622296170462

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 5      266.0  114.0      0.0  228.0               0.0   932.0  670.0   90
# 7      380.0   95.0      0.0  228.0               0.0   932.0  594.0   28
# 8      266.0  114.0      0.0  228.0               0.0   932.0  670.0   28
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 5     47.03
# 7     36.45
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %%
df1.shape
# Out:
# (981, 9)

# %%
# Here we can see that there are around 50 rows removed as they are the OutLiers

# %%
df1.skew()
# Out:
# Cement              0.508557
# Blast               0.747827
# Fly Ash             0.461726
# Water              -0.017778
# Superplasticizer    0.416828
# CA                 -0.087932
# FA                 -0.226214
# Age                 1.940232
# CMS                 0.463962
# dtype: float64

# %%
sns.barplot(x='Age',y='CMS', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# Cement              float64
# Blast               float64
# Fly Ash             float64
# Water               float64
# Superplasticizer    float64
# CA                  float64
# FA                  float64
# Age                   int64
# CMS                 float64
# dtype: object

# %%
# To treate the Skew values

# %%
for col in df1.columns:
    if df1.skew().loc[col]>.55:
        df1[col]=np.log1p(df1[col])

# %%
df1.skew()
# Out:
# Cement              0.508557
# Blast              -0.021576
# Fly Ash             0.461726
# Water              -0.017778
# Superplasticizer    0.416828
# CA                 -0.087932
# FA                 -0.226214
# Age                -0.269706
# CMS                 0.463962
# dtype: float64

# %%
df1.head(10)
# Out:
#     Cement     Blast  Fly Ash  Water  Superplasticizer      CA     FA  \
# 0    540.0  0.000000      0.0  162.0               2.5  1040.0  676.0
# 1    540.0  0.000000      0.0  162.0               2.5  1055.0  676.0
# 5    266.0  4.744932      0.0  228.0               0.0   932.0  670.0
# 7    380.0  4.564348      0.0  228.0               0.0   932.0  594.0
# 8    266.0  4.744932      0.0  228.0               0.0   932.0  670.0
# 9    475.0  0.000000      0.0  228.0               0.0   932.0  594.0
# 10   198.6  4.893352      0.0  192.0               0.0   978.4  825.5
# 11   198.6  4.893352      0.0  192.0               0.0   978.4  825.5
# 13   190.0  5.252273      0.0  228.0               0.0   932.0  670.0
# 14   304.0  4.343805      0.0  228.0               0.0   932.0  670.0
#
#          Age    CMS
# 0   3.367296  79.99
# 1   3.367296  61.89
# 5   4.510860  47.03
# 7   3.367296  36.45
# 8   3.367296  45.85
# 9   3.367296  39.29
# 10  4.510860  38.07
# 11  3.367296  28.02
# ...

# %%
x=df1.iloc[:,0:-1]
x.head()
# Out:
#    Cement     Blast  Fly Ash  Water  Superplasticizer      CA     FA       Age
# 0   540.0  0.000000      0.0  162.0               2.5  1040.0  676.0  3.367296
# 1   540.0  0.000000      0.0  162.0               2.5  1055.0  676.0  3.367296
# 5   266.0  4.744932      0.0  228.0               0.0   932.0  670.0  4.510860
# 7   380.0  4.564348      0.0  228.0               0.0   932.0  594.0  3.367296
# 8   266.0  4.744932      0.0  228.0               0.0   932.0  670.0  3.367296

# %%
y=df1.iloc[:,-1]
y.head()
# Out:
# 0    79.99
# 1    61.89
# 5    47.03
# 7    36.45
# 8    45.85
# Name: CMS, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
max_r_score=0
for r_state in range(40,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=r_state)
    linr=LinearRegression()
    linr.fit(x_train,y_train)
    predlinr=linr.predict(x_test)
    r2scr=r2_score(y_test,predlinr)
    if (r2scr>max_r_score):
        max_r_score=r2scr
        final_r_state=r_state

print("")
print('The max r2-Score corresponding to the',final_r_state,'is',max_r_score)
# Out:
# The max r2-Score corresponding to the 56 is 0.8475118334322088

# %%
x_train.shape
# Out:
# (784, 8)

# %%
x_test.shape
# Out:
# (197, 8)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=56)

# %%
linr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linr.score(x_train,y_train)
# Out:
# 0.8024679749070186

# %%
linr.coef_
# Out:
# array([ 8.69698742e-02,  2.02917560e+00,  1.15750505e-02, -2.63940408e-01,
#         2.61311223e-01, -8.92750391e-03, -2.18588402e-02,  9.64713634e+00])

# %%
linr.intercept_
# Out:
# 46.666130233772776

# %%
predlinr=linr.predict(x_test)

# %%
print('r2-Score is',r2_score(y_test,predlinr))
print(mean_absolute_error(y_test,predlinr))
print('RMSE=',np.sqrt(mean_squared_error(y_test,predlinr)))
# Out:
# r2-Score is 0.8423388924166662
# 5.272201740735873
# RMSE= 6.690748263314879

# %%
# TO Save the model

# %%
from sklearn.externals import joblib

# %%
joblib.dump(linr,'concrete.pkl')
# Out:
# ['concrete.pkl']

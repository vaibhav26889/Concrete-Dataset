# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("happiness.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull(),annot=True)

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
sns.heatmap(df.corr())

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True)

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df['Happiness Score'].plot.box()

# %%
df['Health (Life Expectancy)'].plot.box()

# %%
df['Dystopia Residual'].plot.box()

# %%
df1=df.drop(['Country','Region'],axis=1)
df1
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %% [raw]
# # TO Remove the OUTIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df1))
z
# Out:
# array([[1.72099989, 1.93736005, 0.80592569, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.69907456, 1.91458063, 0.05588945, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.67714922, 1.88479215, 0.8544869 , ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.67742676, 2.0761992 , 0.13253425, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.69935209, 2.1646885 , 2.26396166, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.72127743, 2.22251319, 1.13418227, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
z[27][7]
# Out:
# 3.1646194851713774

# %%
z[157][4]
# Out:
# 3.1347248549706186

# %%
df_new=df1[(z<3).all(axis=1)]
df_new
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 150             151            3.655         0.05141
# 151             152            3.587         0.04324
# 152             153            3.575         0.03084
# 154             155            3.340         0.03656
# 156             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df1.shape
# Out:
# (158, 10)

# %%
# Here we can see that around 10 rows are removed as Outliers

# %%
sns.pairplot(df_new)

# %%
df_new.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
# Now we need to remove the skewness by log function

# %%
for col in df_new.columns:
    if df_new.skew().loc[col]>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
df_new.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.103216
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    0.816117
# Generosity                       0.433539
# Dystopia Residual               -0.021144
# dtype: float64

# %%
df_new.head(10)
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587        0.032458                   1.39651
# 1               2            7.561        0.045530                   1.30232
# 2               3            7.527        0.031706                   1.32548
# 3               4            7.522        0.036679                   1.45900
# 4               5            7.427        0.033742                   1.32629
# 5               6            7.406        0.029994                   1.29025
# 6               7            7.378        0.026867                   1.32944
# 7               8            7.364        0.030150                   1.33171
# 8               9            7.286        0.032096                   1.25018
# 9              10            7.284        0.038488                   1.33358
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
x=df_new.iloc[:,0:9]
x.head(5)
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587        0.032458                   1.39651
# 1               2            7.561        0.045530                   1.30232
# 2               3            7.527        0.031706                   1.32548
# 3               4            7.522        0.036679                   1.45900
# 4               5            7.427        0.033742                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                       0.262731
# 1  1.40223                   0.94784  0.62877                       0.117117
# 2  1.36058                   0.87464  0.64938                       0.287058
# 3  1.33095                   0.88521  0.66973                       0.239745
# 4  1.32261                   0.90563  0.63297                       0.223660
#
#    Generosity
# 0    0.259884
# ...

# %%
y=df_new.iloc[:,-1]
y.head()
# Out:
# 0    2.51738
# 1    2.70201
# 2    2.49204
# 3    2.46531
# 4    2.45176
# Name: Dystopia Residual, dtype: float64

# %%
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
max_r_score=0
for r_state in range(42,105):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=r_state)
    linr=LinearRegression()
    linr.fit(x_train,y_train)
    predlinr=linr.predict(x_test)
    r2score=r2_score(y_test,predlinr)
    if(r2score>max_r_score):
        max_r_score=r2score
        final_r_state=r_state
print("")
print("The maximum value of r2-score corresponding to", final_r_state,'is',max_r_score)
# Out:
# The maximum value of r2-score corresponding to 68 is 0.9996499886273508

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=68)

# %%
linr=LinearRegression()

# %%
linr.fit(x_train,y_train)
linr.score(x_train,y_train)
# Out:
# 0.9988581616268746

# %%
predlinr=linr.predict(x_test)

# %%
print(r2_score(y_test,predlinr))
print(mean_absolute_error(y_test,predlinr))
print('RMSE is: ',np.sqrt(mean_squared_error(y_test,predlinr)))
# Out:
# 0.9996499886273508
# 0.008533957913003272
# RMSE is:  0.010569099411589355

# %%
linr.coef_
# Out:
# array([-2.73513219e-04,  9.89809050e-01,  1.91405917e-01, -1.01251234e+00,
#        -1.00313819e+00, -1.00940316e+00, -9.84374754e-01, -1.58261593e+00,
#        -1.28167491e+00])

# %%
linr.intercept_
# Out:
# 0.14003627198792223
